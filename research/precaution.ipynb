# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data\Disease precaution.csv')

# %%
df
# Out:
#                                     Disease  \
# 0                             Drug Reaction
# 1                                   Malaria
# 2                                   Allergy
# 3                            Hypothyroidism
# 4                                 Psoriasis
# 5                                      GERD
# 6                       Chronic cholestasis
# 7                               hepatitis A
# 8                           Osteoarthristis
# 9   (vertigo) Paroymsal  Positional Vertigo
# 10                             Hypoglycemia
# 11                                     Acne
# 12                                Diabetes
# 13                                 Impetigo
# 14                            Hypertension
# 15                      Peptic ulcer diseae
# 16             Dimorphic hemmorhoids(piles)
# 17                              Common Cold
# 18                              Chicken pox
# 19                     Cervical spondylosis
# ...

# %%
symptoms_list = ['Malaria', 'Migraine', 'Typhoid', 'Pneumonia', 'Chronic cholestasis']

# %%
pp = symptoms_list[3]

# %%
for i in symptoms_list:
    if i == pp:
        causion = df[df['Disease'] == pp]
        c1 = causion["Precaution_1"]
        c2 = causion["Precaution_2"]
        c3 = causion["Precaution_3"]
        c4 = causion["Precaution_4"]
        print(c1.values, c2.values, c3.values, c4.values)
# Out:
# ['consult doctor'] ['medication'] ['rest'] ['follow up']

# %%
def precausion_list(disease:str):
    symptoms_list = ['Malaria', 'Migraine', 'Typhoid', 'Pneumonia', 'Chronic cholestasis']
    for i in symptoms_list:
        if i == disease:
            causion = df[df['Disease'] == disease]
            c1 = causion["Precaution_1"]
            c2 = causion["Precaution_2"]
            c3 = causion["Precaution_3"]
            c4 = causion["Precaution_4"]
    print(c1.values, c2.values, c3.values, c4.values)
    return (c1.values, c2.values, c3.values, c4.values)

# %%
(c1, c2, c3, c4) = precausion_list(disease='Malaria')
# Out:
# ['Consult nearest hospital'] ['avoid oily food'] ['avoid non veg food'] ['keep mosquitos out']
